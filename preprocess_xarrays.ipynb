# %%
import xarray 
import dask 
import numpy as np
import os 
store_dir = os.environ['STORE']
scratch_dir = os.environ['SCRATCH']

# %%
year = 1960
variation = 10

def convert_to_joined_numpy(year,variation):
    Lmon =  xarray.open_mfdataset(f'{store_dir}/s{year}-r{variation}i1p1f1/Lmon/*.nc',compat='minimal')
    Amon =  xarray.open_mfdataset(f'{store_dir}/s{year}-r{variation}i1p1f1/Amon/*.nc',compat='minimal')
    Emon =  xarray.open_mfdataset(f'{store_dir}/s{year}-r{variation}i1p1f1/Emon/*.nc',compat='override')
    # Lmon = Lmon.drop_vars(['time_bounds','landCoverFrac','depth']).drop_dims(['type','axis_nbounds'])
    Lmon = Lmon.drop_vars(['time_bounds','depth_bounds','sector','depth'])
    #Amon = Amon.drop_vars(['time_bounds','hur','hus','o3','ta','ua','va','wap','zg','plev'])
    Amon = Amon.drop_vars(['time_bounds'])
    Emon = Emon.drop_vars(['height','depth','tdps','ppdiat','ppmisc','expfe','olevel_bounds','olevel','flandice','t20d','thetaot','thetaot2000','thetaot300','thetaot700','bounds_nav_lat','bounds_nav_lon','lev','area','type'])
    Emon = Emon.drop_dims(['landuse','x','y','axis_nbounds'])
    #Emon = Emon.drop_vars(['time_bounds','fracLut','sector','type','landuse','nwdFracLut'])
    # variable_list = list(Lmon.keys()) + list(Amon.keys()) + list(Emon.keys())
    # lon,lat = np.meshgrid(Lmon.lon.data,Lmon.lat.data)
    # Lmon['time'] = Lmon.time.astype('float')
    # Amon['time'] = Amon.time.astype('float')
    
    #to convert back, Lmon['time'].astype('datetime64[ns]')
    # time = np.broadcast_to(Lmon.coords['time'],(1,lon.shape[1],lon.shape[2]))
    # time = np.broadcast_to(Lmon.coords['time'],(lon.shape[0],lon.shape[1],len(Lmon.time)))
    # lon = np.broadcast_to(lon,(1,len(Lmon.time),lon.shape[0],lon.shape[1]))
    # lat = np.broadcast_to(lat,(1,len(Lmon.time),lat.shape[0],lat.shape[1]))
    # time = time.reshape(time.shape[2],time.shape[0],time.shape[1])
    # time = time[np.newaxis,:,:,:]
    # total_var_numpy_array = np.concatenate([Lmon.to_array().to_numpy(),Amon.to_array().to_numpy(),Emon.to_array().to_numpy(),lon,lat,time])
   # merged = xarray.merge([Lmon,Amon,Emon])
    xarray.merge([Lmon,Amon,Emon]).to_netcdf(f'{scratch_dir}/{year}_{variation}.nc')
   # return merged
    # np.save(f'{scratch_dir}/{year}_{variation}',total_var_numpy_array)

# %%
x = convert_to_joined_numpy(year,variation)

# %%
x
# Out:
# <xarray.Dataset>
# Dimensions:             (lat: 143, lon: 144, time: 120, type: 15, plev: 19,
#                          solay: 11)
# Coordinates:
#   * lat                 (lat) float32 -90.0 -88.73 -87.46 ... 87.46 88.73 90.0
#   * lon                 (lon) float32 0.0 2.5 5.0 7.5 ... 352.5 355.0 357.5
#   * time                (time) datetime64[ns] 1961-01-16T12:00:00 ... 1970-12...
#   * plev                (plev) float32 1e+05 9.25e+04 8.5e+04 ... 500.0 100.0
#   * solay               (solay) float32 1.0 2.0 3.0 4.0 ... 8.0 9.0 10.0 11.0
# Dimensions without coordinates: type
# Data variables: (12/148)
#     baresoilFrac        (time, lat, lon) float32 dask.array<chunksize=(1, 143, 144), meta=np.ndarray>
#     c3PftFrac           (time, lat, lon) float32 dask.array<chunksize=(1, 143, 144), meta=np.ndarray>
#     c4PftFrac           (time, lat, lon) float32 dask.array<chunksize=(1, 143, 144), meta=np.ndarray>
#     cLeaf               (time, lat, lon) float32 dask.array<chunksize=(1, 143, 144), meta=np.ndarray>
#     cLitter             (time, lat, lon) float32 dask.array<chunksize=(1, 143, 144), meta=np.ndarray>
#     cLitterAbove        (time, lat, lon) float32 dask.array<chunksize=(1, 143, 144), meta=np.ndarray>
#     ...                  ...
#     sfcWindmax          (time, lat, lon) float32 dask.array<chunksize=(1, 143, 144), meta=np.ndarray>
#     treeFracBdlDcd      (time, lat, lon) float32 dask.array<chunksize=(1, 143, 144), meta=np.ndarray>
#     treeFracBdlEvg      (time, lat, lon) float32 dask.array<chunksize=(1, 143, 144), meta=np.ndarray>
#     treeFracNdlDcd      (time, lat, lon) float32 dask.array<chunksize=(1, 143, 144), meta=np.ndarray>
#     treeFracNdlEvg      (time, lat, lon) float32 dask.array<chunksize=(1, 143, 144), meta=np.ndarray>
#     vegFrac             (time, lat, lon) float32 dask.array<chunksize=(1, 143, 144), meta=np.ndarray>
# Attributes: (12/51)
#     name:                   /ccc/work/cont003/gencmip6/flavoni/IGCM_OUT/IPSLC...
#     Conventions:            CF-1.7 CMIP-6.2
#     creation_date:          2019-03-29T15:21:20Z
#     description:            A1 (and A2.1, A3.1, and A3.2) Decadal hindcasts b...
#     title:                  IPSL-CM6A-LR model output prepared for CMIP6 / DC...
#     activity_id:            DCPP
#     ...                     ...
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  22280.0
#     sub_experiment:         initialized near end of year 1960
#     tracking_id:            hdl:21.14100/8a723425-3530-46b7-9d03-f1ead9cf816f
#     further_info_url:       https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM...
#     sub_experiment_id:      s1960
